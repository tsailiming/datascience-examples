# %% [markdown]
# # Obtaining data from API
# We will be using the Python `requests` module. The `requests` module is simplified http module that allows us to quickly pull the data and convert into json.

# %%
import requests

# %% [markdown]
# Let's now try to pull from data.gov.sg's Weekly Infectious Disease Bulletin.
#
# The URL is at
# https://data.gov.sg/dataset/weekly-infectious-disease-bulletin-cases

# %%
api_url = 'https://data.gov.sg/api/action/datastore_search?resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390'
results = requests.get(api_url)

# %% [markdown]
# Let us know look at the JSON data. Most API endpoints returns their data as a JSON data structure. JSON stands for JavaScript Object Notation.

# %%
results.json()
# Out:
# {'help': 'https://data.gov.sg/api/3/action/help_show?name=datastore_search',
#  'result': {'_links': {'next': '/api/action/datastore_search?offset=100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390',
#    'start': '/api/action/datastore_search?resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390'},
#   'fields': [{'id': '_id', 'type': 'int4'},
#    {'id': 'epi_week', 'type': 'text'},
#    {'id': 'disease', 'type': 'text'},
#    {'id': 'no._of_cases', 'type': 'numeric'}],
#   'records': [{'_id': 1,
#     'disease': 'Acute Viral hepatitis B',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 2,
#     'disease': 'Acute Viral hepatitis C',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 3,
#     'disease': 'Avian Influenza',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 4,
#     'disease': 'Chikungunya Fever',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 5,
#     'disease': 'Cholera',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 6,
#     'disease': 'Dengue Haemorrhagic Fever',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 7,
#     'disease': 'Diphtheria',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 8,
#     'disease': 'Encephalitis',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 9,
#     'disease': 'Haemophilus influenzae type b',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 10,
#     'disease': 'Legionellosis',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 11,
#     'disease': 'Melioidosis',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 12,
#     'disease': 'Meningococcal Infection',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 13,
#     'disease': 'Nipah virus infection',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 14,
#     'disease': 'Plague',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 15,
#     'disease': 'Poliomyelitis',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 16, 'disease': 'SARS', 'epi_week': '2012-W01', 'no._of_cases': '0'},
#    {'_id': 17,
#     'disease': 'Yellow Fever',
#     'epi_week': '2012-W01',
#     'no._of_cases': '0'},
#    {'_id': 18,
#     'disease': 'Acute Viral hepatitis B',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 19,
#     'disease': 'Acute Viral hepatitis C',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 20,
#     'disease': 'Avian Influenza',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 21,
#     'disease': 'Cholera',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 22,
#     'disease': 'Diphtheria',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 23,
#     'disease': 'Encephalitis',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 24,
#     'disease': 'Haemophilus influenzae type b',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 25,
#     'disease': 'Legionellosis',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 26,
#     'disease': 'Meningococcal Infection',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 27,
#     'disease': 'Nipah virus infection',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 28,
#     'disease': 'Pertussis',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 29,
#     'disease': 'Plague',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 30,
#     'disease': 'Poliomyelitis',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 31, 'disease': 'SARS', 'epi_week': '2012-W02', 'no._of_cases': '0'},
#    {'_id': 32,
#     'disease': 'Viral Hepatitis E',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 33,
#     'disease': 'Yellow Fever',
#     'epi_week': '2012-W02',
#     'no._of_cases': '0'},
#    {'_id': 34,
#     'disease': 'Acute Viral hepatitis B',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 35,
#     'disease': 'Acute Viral hepatitis C',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 36,
#     'disease': 'Avian Influenza',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 37,
#     'disease': 'Cholera',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 38,
#     'disease': 'Diphtheria',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 39,
#     'disease': 'Haemophilus influenzae type b',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 40,
#     'disease': 'Legionellosis',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 41,
#     'disease': 'Meningococcal Infection',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 42,
#     'disease': 'Nipah virus infection',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 43,
#     'disease': 'Plague',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 44,
#     'disease': 'Poliomyelitis',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 45, 'disease': 'SARS', 'epi_week': '2012-W03', 'no._of_cases': '0'},
#    {'_id': 46,
#     'disease': 'Viral Hepatitis E',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 47,
#     'disease': 'Yellow Fever',
#     'epi_week': '2012-W03',
#     'no._of_cases': '0'},
#    {'_id': 48,
#     'disease': 'Acute Viral hepatitis C',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 49,
#     'disease': 'Avian Influenza',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 50,
#     'disease': 'Chikungunya Fever',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 51,
#     'disease': 'Cholera',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 52,
#     'disease': 'Diphtheria',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 53,
#     'disease': 'Haemophilus influenzae type b',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 54,
#     'disease': 'Measles',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 55,
#     'disease': 'Meningococcal Infection',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 56,
#     'disease': 'Nipah virus infection',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 57,
#     'disease': 'Pertussis',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 58,
#     'disease': 'Plague',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 59,
#     'disease': 'Poliomyelitis',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 60, 'disease': 'SARS', 'epi_week': '2012-W04', 'no._of_cases': '0'},
#    {'_id': 61,
#     'disease': 'Yellow Fever',
#     'epi_week': '2012-W04',
#     'no._of_cases': '0'},
#    {'_id': 62,
#     'disease': 'Acute Viral hepatitis C',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 63,
#     'disease': 'Avian Influenza',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 64,
#     'disease': 'Chikungunya Fever',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 65,
#     'disease': 'Cholera',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 66,
#     'disease': 'Diphtheria',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 67,
#     'disease': 'Encephalitis',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 68,
#     'disease': 'Haemophilus influenzae type b',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 69,
#     'disease': 'Legionellosis',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 70,
#     'disease': 'Melioidosis',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 71,
#     'disease': 'Meningococcal Infection',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 72,
#     'disease': 'Nipah virus infection',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 73,
#     'disease': 'Plague',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 74,
#     'disease': 'Poliomyelitis',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 75,
#     'disease': 'Rubella',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 76, 'disease': 'SARS', 'epi_week': '2012-W05', 'no._of_cases': '0'},
#    {'_id': 77,
#     'disease': 'Viral Hepatitis E',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 78,
#     'disease': 'Yellow Fever',
#     'epi_week': '2012-W05',
#     'no._of_cases': '0'},
#    {'_id': 79,
#     'disease': 'Acute Viral hepatitis C',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 80,
#     'disease': 'Avian Influenza',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 81,
#     'disease': 'Chikungunya Fever',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 82,
#     'disease': 'Cholera',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 83,
#     'disease': 'Dengue Haemorrhagic Fever',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 84,
#     'disease': 'Diphtheria',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 85,
#     'disease': 'Haemophilus influenzae type b',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 86,
#     'disease': 'Meningococcal Infection',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 87,
#     'disease': 'Nipah virus infection',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 88,
#     'disease': 'Pertussis',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 89,
#     'disease': 'Plague',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 90,
#     'disease': 'Poliomyelitis',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 91, 'disease': 'SARS', 'epi_week': '2012-W06', 'no._of_cases': '0'},
#    {'_id': 92,
#     'disease': 'Typhoid',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 93,
#     'disease': 'Viral Hepatitis A',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 94,
#     'disease': 'Yellow Fever',
#     'epi_week': '2012-W06',
#     'no._of_cases': '0'},
#    {'_id': 95,
#     'disease': 'Acute Viral hepatitis B',
#     'epi_week': '2012-W07',
#     'no._of_cases': '0'},
#    {'_id': 96,
#     'disease': 'Acute Viral hepatitis C',
#     'epi_week': '2012-W07',
#     'no._of_cases': '0'},
#    {'_id': 97,
#     'disease': 'Avian Influenza',
#     'epi_week': '2012-W07',
#     'no._of_cases': '0'},
#    {'_id': 98,
#     'disease': 'Chikungunya Fever',
#     'epi_week': '2012-W07',
#     'no._of_cases': '0'},
#    {'_id': 99,
#     'disease': 'Cholera',
#     'epi_week': '2012-W07',
#     'no._of_cases': '0'},
#    {'_id': 100,
#     'disease': 'Dengue Haemorrhagic Fever',
#     'epi_week': '2012-W07',
#     'no._of_cases': '0'}],
#   'resource_id': 'ef7e44f1-9b14-4680-a60a-37d2c9dda390',
#   'total': 14052},
#  'success': True}

# %% [markdown]
# Let's look at the number of records returned.

# %%
data = results.json()
len(data['result']['records'])
# Out:
# 100

# %% [markdown]
# And now look at the total records available.

# %%
data['result']['total']
# Out:
# 14052

# %% [markdown]
# # Pagination in the REST API
# Only 100 records returned but there are a total of 14052 records.
#
# Most API endpoints limits the number of records returned within a single call to prevent overwhelming the system.

# %% [markdown]
# Get the next page of results using the offset returned by the API call

# %%
data['result']['_links']
# Out:
# {'next': '/api/action/datastore_search?offset=100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390',
#  'start': '/api/action/datastore_search?resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390'}

# %%
results = requests.get('https://data.gov.sg' + '/api/action/datastore_search?offset=100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390')

# %%
results.json()['result']['records']
# Out:
# [{'_id': 101,
#   'disease': 'Diphtheria',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 102,
#   'disease': 'Encephalitis',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 103,
#   'disease': 'Haemophilus influenzae type b',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 104,
#   'disease': 'Legionellosis',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 105,
#   'disease': 'Melioidosis',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 106,
#   'disease': 'Meningococcal Infection',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 107,
#   'disease': 'Nipah virus infection',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 108,
#   'disease': 'Pertussis',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 109,
#   'disease': 'Plague',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 110,
#   'disease': 'Poliomyelitis',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 111, 'disease': 'SARS', 'epi_week': '2012-W07', 'no._of_cases': '0'},
#  {'_id': 112,
#   'disease': 'Viral Hepatitis A',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 113,
#   'disease': 'Yellow Fever',
#   'epi_week': '2012-W07',
#   'no._of_cases': '0'},
#  {'_id': 114,
#   'disease': 'Acute Viral hepatitis B',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 115,
#   'disease': 'Acute Viral hepatitis C',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 116,
#   'disease': 'Avian Influenza',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 117,
#   'disease': 'Cholera',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 118,
#   'disease': 'Diphtheria',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 119,
#   'disease': 'Encephalitis',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 120,
#   'disease': 'Haemophilus influenzae type b',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 121,
#   'disease': 'Legionellosis',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 122,
#   'disease': 'Malaria',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 123,
#   'disease': 'Meningococcal Infection',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 124,
#   'disease': 'Nipah virus infection',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 125,
#   'disease': 'Pertussis',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 126,
#   'disease': 'Plague',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 127,
#   'disease': 'Poliomyelitis',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 128,
#   'disease': 'Rubella',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 129, 'disease': 'SARS', 'epi_week': '2012-W08', 'no._of_cases': '0'},
#  {'_id': 130,
#   'disease': 'Viral Hepatitis A',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 131,
#   'disease': 'Yellow Fever',
#   'epi_week': '2012-W08',
#   'no._of_cases': '0'},
#  {'_id': 132,
#   'disease': 'Acute Viral hepatitis C',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 133,
#   'disease': 'Avian Influenza',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 134,
#   'disease': 'Cholera',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 135,
#   'disease': 'Dengue Haemorrhagic Fever',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 136,
#   'disease': 'Diphtheria',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 137,
#   'disease': 'Encephalitis',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 138,
#   'disease': 'Haemophilus influenzae type b',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 139,
#   'disease': 'Malaria',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 140,
#   'disease': 'Meningococcal Infection',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 141,
#   'disease': 'Nipah virus infection',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 142,
#   'disease': 'Plague',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 143,
#   'disease': 'Poliomyelitis',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 144, 'disease': 'SARS', 'epi_week': '2012-W09', 'no._of_cases': '0'},
#  {'_id': 145,
#   'disease': 'Viral Hepatitis E',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 146,
#   'disease': 'Yellow Fever',
#   'epi_week': '2012-W09',
#   'no._of_cases': '0'},
#  {'_id': 147,
#   'disease': 'Avian Influenza',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 148,
#   'disease': 'Cholera',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 149,
#   'disease': 'Diphtheria',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 150,
#   'disease': 'Haemophilus influenzae type b',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 151,
#   'disease': 'Measles',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 152,
#   'disease': 'Melioidosis',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 153,
#   'disease': 'Meningococcal Infection',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 154,
#   'disease': 'Nipah virus infection',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 155,
#   'disease': 'Pertussis',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 156,
#   'disease': 'Plague',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 157,
#   'disease': 'Poliomyelitis',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 158,
#   'disease': 'Rubella',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 159, 'disease': 'SARS', 'epi_week': '2012-W10', 'no._of_cases': '0'},
#  {'_id': 160,
#   'disease': 'Yellow Fever',
#   'epi_week': '2012-W10',
#   'no._of_cases': '0'},
#  {'_id': 161,
#   'disease': 'Acute Viral hepatitis B',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 162,
#   'disease': 'Acute Viral hepatitis C',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 163,
#   'disease': 'Avian Influenza',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 164,
#   'disease': 'Chikungunya Fever',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 165,
#   'disease': 'Cholera',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 166,
#   'disease': 'Dengue Haemorrhagic Fever',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 167,
#   'disease': 'Diphtheria',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 168,
#   'disease': 'Haemophilus influenzae type b',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 169,
#   'disease': 'Meningococcal Infection',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 170,
#   'disease': 'Nipah virus infection',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 171,
#   'disease': 'Pertussis',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 172,
#   'disease': 'Plague',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 173,
#   'disease': 'Poliomyelitis',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 174, 'disease': 'SARS', 'epi_week': '2012-W11', 'no._of_cases': '0'},
#  {'_id': 175,
#   'disease': 'Yellow Fever',
#   'epi_week': '2012-W11',
#   'no._of_cases': '0'},
#  {'_id': 176,
#   'disease': 'Acute Viral hepatitis C',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 177,
#   'disease': 'Avian Influenza',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 178,
#   'disease': 'Chikungunya Fever',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 179,
#   'disease': 'Cholera',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 180,
#   'disease': 'Diphtheria',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 181,
#   'disease': 'Haemophilus influenzae type b',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 182,
#   'disease': 'Melioidosis',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 183,
#   'disease': 'Meningococcal Infection',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 184,
#   'disease': 'Nipah virus infection',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 185,
#   'disease': 'Plague',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 186,
#   'disease': 'Poliomyelitis',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 187,
#   'disease': 'Rubella',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 188, 'disease': 'SARS', 'epi_week': '2012-W12', 'no._of_cases': '0'},
#  {'_id': 189,
#   'disease': 'Viral Hepatitis A',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 190,
#   'disease': 'Yellow Fever',
#   'epi_week': '2012-W12',
#   'no._of_cases': '0'},
#  {'_id': 191,
#   'disease': 'Acute Viral hepatitis C',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'},
#  {'_id': 192,
#   'disease': 'Avian Influenza',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'},
#  {'_id': 193,
#   'disease': 'Chikungunya Fever',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'},
#  {'_id': 194,
#   'disease': 'Cholera',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'},
#  {'_id': 195,
#   'disease': 'Dengue Haemorrhagic Fever',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'},
#  {'_id': 196,
#   'disease': 'Diphtheria',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'},
#  {'_id': 197,
#   'disease': 'Encephalitis',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'},
#  {'_id': 198,
#   'disease': 'Haemophilus influenzae type b',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'},
#  {'_id': 199,
#   'disease': 'Measles',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'},
#  {'_id': 200,
#   'disease': 'Melioidosis',
#   'epi_week': '2012-W13',
#   'no._of_cases': '0'}]

# %% [markdown]
# Now, let's write a single loop to paginate through the API to obtain all the data.

# %%
data_gov_domain = 'https://data.gov.sg'
url = data_gov_domain + '/api/action/datastore_search?resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390'
records = []

record_len = 1

while record_len > 0:
  response = requests.get(url)

  if response.status_code != 200:
    print('Opps! Something went wrong!')
    break

  data = response.json()
  record_len = len(data['result']['records'])

  records.extend(data['result']['records'])
  url = data_gov_domain + data['result']['_links']['next']
# Out:
# https://data.gov.sg/api/action/datastore_search?resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=1900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=2900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=3900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=4900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=5900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=6900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=7900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=8900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=9900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=10900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=11900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=12900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13200&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13300&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13400&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13500&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13600&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13700&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13800&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=13900&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=14000&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390
# https://data.gov.sg/api/action/datastore_search?offset=14100&resource_id=ef7e44f1-9b14-4680-a60a-37d2c9dda390

# %%
len(records)
# Out:
# 14052

# %% [markdown]
# List the first 5 records

# %%
records[:5]
# Out:
# [{'_id': 1,
#   'disease': 'Acute Viral hepatitis B',
#   'epi_week': '2012-W01',
#   'no._of_cases': '0'},
#  {'_id': 2,
#   'disease': 'Acute Viral hepatitis C',
#   'epi_week': '2012-W01',
#   'no._of_cases': '0'},
#  {'_id': 3,
#   'disease': 'Avian Influenza',
#   'epi_week': '2012-W01',
#   'no._of_cases': '0'},
#  {'_id': 4,
#   'disease': 'Chikungunya Fever',
#   'epi_week': '2012-W01',
#   'no._of_cases': '0'},
#  {'_id': 5, 'disease': 'Cholera', 'epi_week': '2012-W01', 'no._of_cases': '0'}]

# %% [markdown]
# # Let us now convert to a Pandas DataFrame

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(records)

# %%
df.head(10)
# Out:
#    epi_week  _id                        disease no._of_cases
# 0  2012-W01    1        Acute Viral hepatitis B            0
# 1  2012-W01    2        Acute Viral hepatitis C            0
# 2  2012-W01    3                Avian Influenza            0
# 3  2012-W01    4              Chikungunya Fever            0
# 4  2012-W01    5                        Cholera            0
# 5  2012-W01    6      Dengue Haemorrhagic Fever            0
# 6  2012-W01    7                     Diphtheria            0
# 7  2012-W01    8                   Encephalitis            0
# 8  2012-W01    9  Haemophilus influenzae type b            0
# 9  2012-W01   10                  Legionellosis            0

# %% [markdown]
# Let's change the column names to something more presentable.

# %%
df.columns= ['EPI Week', 'ID', 'Disease', 'No of Cases']

# %%
df.head(10)
# Out:
#    EPI Week  ID                        Disease No of Cases
# 0  2012-W01   1        Acute Viral hepatitis B           0
# 1  2012-W01   2        Acute Viral hepatitis C           0
# 2  2012-W01   3                Avian Influenza           0
# 3  2012-W01   4              Chikungunya Fever           0
# 4  2012-W01   5                        Cholera           0
# 5  2012-W01   6      Dengue Haemorrhagic Fever           0
# 6  2012-W01   7                     Diphtheria           0
# 7  2012-W01   8                   Encephalitis           0
# 8  2012-W01   9  Haemophilus influenzae type b           0
# 9  2012-W01  10                  Legionellosis           0

# %%
df.dtypes
# Out:
# EPI Week       object
# ID              int64
# Disease        object
# No of Cases    object
# dtype: object

# %%
df['No of Cases'] = pd.to_numeric(df['No of Cases'])

# %%
df.dtypes
# Out:
# EPI Week       object
# ID              int64
# Disease        object
# No of Cases     int64
# dtype: object

# %%
df[df['No of Cases'].between(5,10)]
# Out:
#        EPI Week     ID                          Disease  No of Cases
# 11793  2016-W20  12018                          Measles            6
# 11824  2012-W03  11814                        Pertussis            5
# 11825  2012-W03  11815                          Typhoid            5
# 11826  2012-W05  11816  Pneumococcal Disease (invasive)            5
# 11827  2012-W05  11817                          Typhoid            5
# ...         ...    ...                              ...          ...
# 12486  2019-W31  12477                          Measles           10
# 12487  2019-W45  12478                            Mumps           10
# 12488  2019-W48  12479                            Mumps           10
# 12489  2019-W48  12480          Campylobacter enteritis           10
# 12490  2019-W51  12481                            Mumps           10
#
# [668 rows x 4 columns]
